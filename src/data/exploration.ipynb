# %%
import pandas as pd
df = pd.read_csv ('../../data/raw/VN_housing_dataset.csv')

# delete count column and final rows because it's have ilegal values
df = df.iloc[:-1, 1:]

# %%
df_without_pre_proccessing = df

df
# Out:
#              Ngày                                            Địa chỉ  \
# 0      2020-08-05  Đường Hoàng Quốc Việt, Phường Nghĩa Đô, Quận C...
# 1      2020-08-05  Đường Kim Giang, Phường Kim Giang, Quận Thanh ...
# 2      2020-08-05  phố minh khai, Phường Minh Khai, Quận Hai Bà T...
# 3      2020-08-05  Đường Võng Thị, Phường Thụy Khuê, Quận Tây Hồ,...
# 4      2020-08-05  Đường Kim Giang, Phường Kim Giang, Quận Thanh ...
# ...           ...                                                ...
# 82490  2019-08-26  Đường Lê Đức Thọ, Phường Mỹ Đình 1, Quận Nam T...
# 82491  2019-08-23  Đường Hồ Tùng Mậu, Phường Phúc Diễn, Quận Bắc ...
# 82492  2019-08-07  Đường Trần Quốc Hoàn, Phường Quan Hoa, Quận Cầ...
# 82493  2019-08-07  Đường Nguyễn Khánh Toàn, Phường Quan Hoa, Quận...
# 82494  2019-08-05  Đường Quan Hoa, Phường Quan Hoa, Quận Cầu Giấy...
#
#                     Quận             Huyện        Loại hình nhà ở  \
# 0          Quận Cầu Giấy   Phường Nghĩa Đô           Nhà ngõ, hẻm
# 1        Quận Thanh Xuân  Phường Kim Giang  Nhà mặt phố, mặt tiền
# 2      Quận Hai Bà Trưng  Phường Minh Khai           Nhà ngõ, hẻm
# 3            Quận Tây Hồ  Phường Thụy Khuê           Nhà ngõ, hẻm
# 4        Quận Thanh Xuân  Phường Kim Giang           Nhà ngõ, hẻm
# ...                  ...               ...                    ...
# 82490   Quận Nam Từ Liêm  Phường Mỹ Đình 1        Nhà phố liền kề
# 82491   Quận Bắc Từ Liêm  Phường Phúc Diễn        Nhà phố liền kề
# 82492      Quận Cầu Giấy   Phường Quan Hoa  Nhà mặt phố, mặt tiền
# 82493      Quận Cầu Giấy   Phường Quan Hoa  Nhà mặt phố, mặt tiền
# 82494      Quận Cầu Giấy   Phường Quan Hoa           Nhà ngõ, hẻm
#
#       Giấy tờ pháp lý Số tầng Số phòng ngủ Diện tích      Dài Rộng  \
# 0            Đã có sổ       4      5 phòng     46 m²      NaN  NaN
# 1                 NaN     NaN      3 phòng     37 m²      NaN  NaN
# 2            Đã có sổ       4      4 phòng     40 m²     10 m  4 m
# 3            Đã có sổ     NaN      6 phòng     51 m²  12.75 m  4 m
# 4                 NaN     NaN      4 phòng     36 m²      9 m  4 m
# ...               ...     ...          ...       ...      ...  ...
# 82490        Đã có sổ     NaN      3 phòng     38 m²      NaN  NaN
# 82491             NaN     NaN      3 phòng     38 m²      NaN  NaN
# 82492             NaN     NaN      3 phòng     50 m²      NaN  NaN
# 82493        Đã có sổ     NaN      4 phòng     41 m²      NaN  NaN
# 82494        Đã có sổ     NaN      4 phòng     60 m²      NaN  NaN
#
#                 Giá/m2
# 0       86,96 triệu/m²
# 1      116,22 triệu/m²
# 2          65 triệu/m²
# 3         100 triệu/m²
# 4       86,11 triệu/m²
# ...                ...
# 82490   76,32 triệu/m²
# 82491   81,58 triệu/m²
# 82492     292 triệu/m²
# 82493  341,46 triệu/m²
# 82494  101,67 triệu/m²
#
# [82495 rows x 12 columns]

# %% [markdown]
# <h5><span>How many rows and how many columns?</span></h5>

# %%
n_rows, n_cols = df.shape

# %%
n_rows
# Out:
# 82495

# %%
n_cols
# Out:
# 12

# %% [markdown]
# <h5>What is the meaning of each row?</h5>

# %% [markdown]
# <span>Each row is management some significant information of a house like address, number of rooms, number of floors, squares,
# price,..etc</span>

# %% [markdown]
# <h5>Are there duplicated rows?</h5>

# %%
num_duplicated_rows = df.duplicated().sum()
num_duplicated_rows
# Out:
# 815

# %% [markdown]
# <h5>Remove duplicated rows</h5>

# %%
df = df.drop_duplicates()
df
# Out:
#              Ngày                                            Địa chỉ  \
# 0      2020-08-05  Đường Hoàng Quốc Việt, Phường Nghĩa Đô, Quận C...
# 1      2020-08-05  Đường Kim Giang, Phường Kim Giang, Quận Thanh ...
# 2      2020-08-05  phố minh khai, Phường Minh Khai, Quận Hai Bà T...
# 3      2020-08-05  Đường Võng Thị, Phường Thụy Khuê, Quận Tây Hồ,...
# 4      2020-08-05  Đường Kim Giang, Phường Kim Giang, Quận Thanh ...
# ...           ...                                                ...
# 82490  2019-08-26  Đường Lê Đức Thọ, Phường Mỹ Đình 1, Quận Nam T...
# 82491  2019-08-23  Đường Hồ Tùng Mậu, Phường Phúc Diễn, Quận Bắc ...
# 82492  2019-08-07  Đường Trần Quốc Hoàn, Phường Quan Hoa, Quận Cầ...
# 82493  2019-08-07  Đường Nguyễn Khánh Toàn, Phường Quan Hoa, Quận...
# 82494  2019-08-05  Đường Quan Hoa, Phường Quan Hoa, Quận Cầu Giấy...
#
#                     Quận             Huyện        Loại hình nhà ở  \
# 0          Quận Cầu Giấy   Phường Nghĩa Đô           Nhà ngõ, hẻm
# 1        Quận Thanh Xuân  Phường Kim Giang  Nhà mặt phố, mặt tiền
# 2      Quận Hai Bà Trưng  Phường Minh Khai           Nhà ngõ, hẻm
# 3            Quận Tây Hồ  Phường Thụy Khuê           Nhà ngõ, hẻm
# 4        Quận Thanh Xuân  Phường Kim Giang           Nhà ngõ, hẻm
# ...                  ...               ...                    ...
# 82490   Quận Nam Từ Liêm  Phường Mỹ Đình 1        Nhà phố liền kề
# 82491   Quận Bắc Từ Liêm  Phường Phúc Diễn        Nhà phố liền kề
# 82492      Quận Cầu Giấy   Phường Quan Hoa  Nhà mặt phố, mặt tiền
# 82493      Quận Cầu Giấy   Phường Quan Hoa  Nhà mặt phố, mặt tiền
# 82494      Quận Cầu Giấy   Phường Quan Hoa           Nhà ngõ, hẻm
#
#       Giấy tờ pháp lý Số tầng Số phòng ngủ Diện tích      Dài Rộng  \
# 0            Đã có sổ       4      5 phòng     46 m²      NaN  NaN
# 1                 NaN     NaN      3 phòng     37 m²      NaN  NaN
# 2            Đã có sổ       4      4 phòng     40 m²     10 m  4 m
# 3            Đã có sổ     NaN      6 phòng     51 m²  12.75 m  4 m
# 4                 NaN     NaN      4 phòng     36 m²      9 m  4 m
# ...               ...     ...          ...       ...      ...  ...
# 82490        Đã có sổ     NaN      3 phòng     38 m²      NaN  NaN
# 82491             NaN     NaN      3 phòng     38 m²      NaN  NaN
# 82492             NaN     NaN      3 phòng     50 m²      NaN  NaN
# 82493        Đã có sổ     NaN      4 phòng     41 m²      NaN  NaN
# 82494        Đã có sổ     NaN      4 phòng     60 m²      NaN  NaN
#
#                 Giá/m2
# 0       86,96 triệu/m²
# 1      116,22 triệu/m²
# 2          65 triệu/m²
# 3         100 triệu/m²
# 4       86,11 triệu/m²
# ...                ...
# 82490   76,32 triệu/m²
# 82491   81,58 triệu/m²
# 82492     292 triệu/m²
# 82493  341,46 triệu/m²
# 82494  101,67 triệu/m²
#
# [81680 rows x 12 columns]

# %% [markdown]
# <h5>What is the meaning of each column?</h5>

# %%
rename_lst = ['date', 'address', 'district', 'town', 'house_type', 'paper_type', 'num_floors', 'num_rooms', 
              'squares', 'length', 'width', 'price_per_m2']
df.columns = rename_lst
df
# Out:
#              date                                            address  \
# 0      2020-08-05  Đường Hoàng Quốc Việt, Phường Nghĩa Đô, Quận C...
# 1      2020-08-05  Đường Kim Giang, Phường Kim Giang, Quận Thanh ...
# 2      2020-08-05  phố minh khai, Phường Minh Khai, Quận Hai Bà T...
# 3      2020-08-05  Đường Võng Thị, Phường Thụy Khuê, Quận Tây Hồ,...
# 4      2020-08-05  Đường Kim Giang, Phường Kim Giang, Quận Thanh ...
# ...           ...                                                ...
# 82490  2019-08-26  Đường Lê Đức Thọ, Phường Mỹ Đình 1, Quận Nam T...
# 82491  2019-08-23  Đường Hồ Tùng Mậu, Phường Phúc Diễn, Quận Bắc ...
# 82492  2019-08-07  Đường Trần Quốc Hoàn, Phường Quan Hoa, Quận Cầ...
# 82493  2019-08-07  Đường Nguyễn Khánh Toàn, Phường Quan Hoa, Quận...
# 82494  2019-08-05  Đường Quan Hoa, Phường Quan Hoa, Quận Cầu Giấy...
#
#                 district              town             house_type paper_type  \
# 0          Quận Cầu Giấy   Phường Nghĩa Đô           Nhà ngõ, hẻm   Đã có sổ
# 1        Quận Thanh Xuân  Phường Kim Giang  Nhà mặt phố, mặt tiền        NaN
# 2      Quận Hai Bà Trưng  Phường Minh Khai           Nhà ngõ, hẻm   Đã có sổ
# 3            Quận Tây Hồ  Phường Thụy Khuê           Nhà ngõ, hẻm   Đã có sổ
# 4        Quận Thanh Xuân  Phường Kim Giang           Nhà ngõ, hẻm        NaN
# ...                  ...               ...                    ...        ...
# 82490   Quận Nam Từ Liêm  Phường Mỹ Đình 1        Nhà phố liền kề   Đã có sổ
# 82491   Quận Bắc Từ Liêm  Phường Phúc Diễn        Nhà phố liền kề        NaN
# 82492      Quận Cầu Giấy   Phường Quan Hoa  Nhà mặt phố, mặt tiền        NaN
# 82493      Quận Cầu Giấy   Phường Quan Hoa  Nhà mặt phố, mặt tiền   Đã có sổ
# 82494      Quận Cầu Giấy   Phường Quan Hoa           Nhà ngõ, hẻm   Đã có sổ
#
#       num_floors num_rooms squares   length width     price_per_m2
# 0              4   5 phòng   46 m²      NaN   NaN   86,96 triệu/m²
# 1            NaN   3 phòng   37 m²      NaN   NaN  116,22 triệu/m²
# 2              4   4 phòng   40 m²     10 m   4 m      65 triệu/m²
# 3            NaN   6 phòng   51 m²  12.75 m   4 m     100 triệu/m²
# 4            NaN   4 phòng   36 m²      9 m   4 m   86,11 triệu/m²
# ...          ...       ...     ...      ...   ...              ...
# 82490        NaN   3 phòng   38 m²      NaN   NaN   76,32 triệu/m²
# 82491        NaN   3 phòng   38 m²      NaN   NaN   81,58 triệu/m²
# 82492        NaN   3 phòng   50 m²      NaN   NaN     292 triệu/m²
# 82493        NaN   4 phòng   41 m²      NaN   NaN  341,46 triệu/m²
# 82494        NaN   4 phòng   60 m²      NaN   NaN  101,67 triệu/m²
#
# [81680 rows x 12 columns]

# %% [markdown]
# <ul><h5>The meaning of all columns</h5>
#     <li>date: The date the house is published to sell. </li>
#     <li>address: House's address. </li>
#     <li>district: House's district. </li>
#     <li>town: House's town. </li>
#     <li>house_type: House's type</li>
#     <li>paper_type: House's paper work</li>
#     <li>num_floors: How many floors are there in this house?</li>
#     <li>num_rooms: How many rooms are there in this house?</li>
#     <li>squares: Houes's squares</li>
#     <li>length: House's length</li>
#     <li>width: House's width</li>
#     <li>price_per_m2: price per m2</li>
# </ul>

# %% [markdown]
# <h5>What is the current data type of each column? Are there columns having
# inappropriate data types?</h5>

# %%
df.dtypes
# Out:
# date            object
# address         object
# district        object
# town            object
# house_type      object
# paper_type      object
# num_floors      object
# num_rooms       object
# squares         object
# length          object
# width           object
# price_per_m2    object
# dtype: object

# %%
# preproccesing for num_floors, num_rooms, squares, length, width, price_per_m2

import math
import re


def nan_to_0(value):
    result = 0
    
    try:
        result = re.findall(r"[-+]?\d*\,?\d+|\d+", value)[0].replace(",", ".")
        result = int(result) if result.find(".") == -1 else float(result) 

    except:
        result = 0
    
    return result

# %%
import math

def nan_to_0_or_1(value):
    result = 0
    
    try:
        float(value)
        result = 0
    except:
        result = 1
    
    return result

# %%
num_floors = df["num_floors"].tolist()
num_rooms = df["num_rooms"].tolist()
squares = df["squares"].tolist()
length = df["length"].tolist()
width = df["width"].tolist()
price_per_m2 = df["price_per_m2"].tolist()
paper_type = df["paper_type"].tolist()


num_floors = map(nan_to_0, num_floors)
num_rooms = map(nan_to_0, num_rooms)
squares =  map(nan_to_0, squares)
length =  map(nan_to_0, length)
width =  map(nan_to_0, width) 
price_per_m2 =  map(nan_to_0, price_per_m2)
paper_type = map(nan_to_0_or_1, paper_type)


df["num_floors"] = list(num_floors)
df["num_rooms"] = list(num_rooms)
df["squares"] = list(squares)
df["length"] = list(length)
df["width"] = list(width)
df["price_per_m2"] = list(price_per_m2)
df["paper_type"] = list(paper_type)
# Out:
# C:\Users\gohuy\AppData\Local\Temp\ipykernel_25200\2970549655.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["num_floors"] = list(num_floors)
# C:\Users\gohuy\AppData\Local\Temp\ipykernel_25200\2970549655.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["num_rooms"] = list(num_rooms)
# C:\Users\gohuy\AppData\Local\Temp\ipykernel_25200\2970549655.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["squares"] = list(squares)
# C:\Users\gohuy\AppData\Local\Temp\ipykernel_25200\2970549655.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["length"] = list(length)
# C:\Users\gohuy\AppData\Local\Temp\ipykernel_25200\2970549655.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["width"] = list(width)
# C:\Users\gohuy\AppData\Local\Temp\ipykernel_25200\2970549655.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["price_per_m2"] = list(price_per_m2)
# C:\Users\gohuy\AppData\Local\Temp\ipykernel_25200\2970549655.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["paper_type"] = list(paper_type)

# %%
indexAge = df[ (df['length'] >= 1000) | (df['width'] >= 1000) | (df['squares'] >= 1000)].index
df.drop(indexAge , inplace=True)
# Phan Huy drop price value 0!
df = df[(df['price_per_m2'] != 0.0)]
# Out:
# C:\Users\gohuy\AppData\Local\Temp\ipykernel_25200\996155145.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(indexAge , inplace=True)

# %%
df
# Out:
#              date                                            address  \
# 0      2020-08-05  Đường Hoàng Quốc Việt, Phường Nghĩa Đô, Quận C...
# 1      2020-08-05  Đường Kim Giang, Phường Kim Giang, Quận Thanh ...
# 2      2020-08-05  phố minh khai, Phường Minh Khai, Quận Hai Bà T...
# 3      2020-08-05  Đường Võng Thị, Phường Thụy Khuê, Quận Tây Hồ,...
# 4      2020-08-05  Đường Kim Giang, Phường Kim Giang, Quận Thanh ...
# ...           ...                                                ...
# 82490  2019-08-26  Đường Lê Đức Thọ, Phường Mỹ Đình 1, Quận Nam T...
# 82491  2019-08-23  Đường Hồ Tùng Mậu, Phường Phúc Diễn, Quận Bắc ...
# 82492  2019-08-07  Đường Trần Quốc Hoàn, Phường Quan Hoa, Quận Cầ...
# 82493  2019-08-07  Đường Nguyễn Khánh Toàn, Phường Quan Hoa, Quận...
# 82494  2019-08-05  Đường Quan Hoa, Phường Quan Hoa, Quận Cầu Giấy...
#
#                 district              town             house_type  paper_type  \
# 0          Quận Cầu Giấy   Phường Nghĩa Đô           Nhà ngõ, hẻm           1
# 1        Quận Thanh Xuân  Phường Kim Giang  Nhà mặt phố, mặt tiền           0
# 2      Quận Hai Bà Trưng  Phường Minh Khai           Nhà ngõ, hẻm           1
# 3            Quận Tây Hồ  Phường Thụy Khuê           Nhà ngõ, hẻm           1
# 4        Quận Thanh Xuân  Phường Kim Giang           Nhà ngõ, hẻm           0
# ...                  ...               ...                    ...         ...
# 82490   Quận Nam Từ Liêm  Phường Mỹ Đình 1        Nhà phố liền kề           1
# 82491   Quận Bắc Từ Liêm  Phường Phúc Diễn        Nhà phố liền kề           0
# 82492      Quận Cầu Giấy   Phường Quan Hoa  Nhà mặt phố, mặt tiền           0
# 82493      Quận Cầu Giấy   Phường Quan Hoa  Nhà mặt phố, mặt tiền           1
# 82494      Quận Cầu Giấy   Phường Quan Hoa           Nhà ngõ, hẻm           1
#
#        num_floors  num_rooms  squares  length  width  price_per_m2
# 0               4          5       46       0      0         86.96
# 1               0          3       37       0      0        116.22
# 2               4          4       40      10      4         65.00
# 3               0          6       51      12      4        100.00
# 4               0          4       36       9      4         86.11
# ...           ...        ...      ...     ...    ...           ...
# 82490           0          3       38       0      0         76.32
# 82491           0          3       38       0      0         81.58
# 82492           0          3       50       0      0        292.00
# 82493           0          4       41       0      0        341.46
# 82494           0          4       60       0      0        101.67
#
# [81525 rows x 12 columns]

# %%
df.to_csv("../../data/processed/VN_housing_dataset.csv", index=False)

# %% [markdown]
# <h5>With each numerical column, how are values distributed?</h5>

# %%
import seaborn as sns

sns.set_style("whitegrid")# Set dạng hiển thị: darkgrid, whitegrid, dark, white, ticks

# %%
sns.histplot(df['price_per_m2'])
# Out:
# <AxesSubplot: xlabel='price_per_m2', ylabel='Count'>

# %%
sns.histplot(df['paper_type'])
# Out:
# <AxesSubplot: xlabel='paper_type', ylabel='Count'>

# %%
sns.histplot(df['num_floors'])
# Out:
# <AxesSubplot: xlabel='num_floors', ylabel='Count'>

# %%
sns.histplot(df['num_rooms'])
# Out:
# <AxesSubplot: xlabel='num_rooms', ylabel='Count'>

# %%
sns.histplot(df['squares'])
# Out:
# <AxesSubplot: xlabel='squares', ylabel='Count'>

# %%
sns.histplot(df['length'])
# Out:
# <AxesSubplot: xlabel='length', ylabel='Count'>

# %%
sns.histplot(df['width'])
# Out:
# <AxesSubplot: xlabel='width', ylabel='Count'>

# %% [markdown]
# <h5>What is the percentage of missing values?</h5>

# %%
percent_missing = df_without_pre_proccessing.isnull().sum() * 100 / len(df_without_pre_proccessing)
missing_value_df = pd.DataFrame({'column_name': df_without_pre_proccessing.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                      column_name  percent_missing
# Ngày                        Ngày         0.000000
# Địa chỉ                  Địa chỉ         0.056973
# Quận                        Quận         0.001212
# Huyện                      Huyện         0.056973
# Loại hình nhà ở  Loại hình nhà ở         0.037578
# Giấy tờ pháp lý  Giấy tờ pháp lý        35.014243
# Số tầng                  Số tầng        55.877326
# Số phòng ngủ        Số phòng ngủ         0.046063
# Diện tích              Diện tích         0.001212
# Dài                          Dài        75.965816
# Rộng                        Rộng        57.033760
# Giá/m2                    Giá/m2         0.014546

# %% [markdown]
# <h5>Min? max? Are they abnormal?</h5>

# %%
num_floors_max = df['num_floors'].max()
num_rooms_max = df['num_rooms'].max()
squares_max = df['squares'].max()
length_max = df['length'].max()
width_max = df['width'].max()
price_per_m2_max = df['price_per_m2'].max()

max_values = [num_floors_max, num_rooms_max, squares_max, length_max, width_max, price_per_m2_max]

header = ["num_floors(num)", "num_rooms(num)", "squares(m2)", "length(m)", "width(m)", "price_per_m2(VND)"]

max_df = pd.DataFrame(max_values, header, columns=["Max"])
max_df
# Out:
#                      Max
# num_floors(num)     73.0
# num_rooms(num)      10.0
# squares(m2)        888.0
# length(m)          986.0
# width(m)           930.0
# price_per_m2(VND)  998.0

# %%
num_floors_min = df['num_floors'].min()
num_rooms_min = df['num_rooms'].min()
squares_min = df['squares'].min()
length_min = df['length'].min()
width_min = df['width'].max()
price_per_m2_min = df['price_per_m2'].min()

min_values = [num_floors_min, num_rooms_min, squares_min, length_min, width_min, price_per_m2_min]

header = ["num_floors(num)", "num_rooms(num)", "squares(m2)", "length(m)", "width(m)", "price_per_m2(VND)"]

min_df = pd.DataFrame(min_values, header, columns=["Min"])
min_df
# Out:
#                      Min
# num_floors(num)      0.0
# num_rooms(num)       0.0
# squares(m2)          1.0
# length(m)            0.0
# width(m)           930.0
# price_per_m2(VND)    1.0

# %% [markdown]
# <h5>With each categorical column, how are values distributed?</h5>

# %%
import numpy as np

categories = df.loc[:,df.dtypes==np.object]
categories
# Out:
# C:\Users\gohuy\AppData\Local\Temp\ipykernel_25200\4262902076.py:3: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.  (This may have returned Python scalars in past versions.
#   categories = df.loc[:,df.dtypes==np.object]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [27], line 3
#       1 import numpy as np
# ----> 3 categories = df.loc[:,df.dtypes==np.object]
#       4 categories
#
# File c:\Users\gohuy\anaconda3\envs\VNH\lib\site-packages\numpy\__init__.py:284, in __getattr__(attr)
#     281     from .testing import Tester
#     282     return Tester
# --> 284 raise AttributeError("module {!r} has no attribute "
#     285                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'object'

# %%
import matplotlib.pyplot as plt
import math

def draw_category_with_offset_limit(category, offset, limit):
    fig, ax = plt.subplots(figsize=(20, 10))
    sns.barplot(x = category.index, y = category.values, ax=ax)
    ax.set_xticklabels(ax.get_xticklabels(), rotation = 50)

    ax.set_xlim(offset * 40, limit * 40)
    plt.show()

# %%
house_type_category = categories.groupby('house_type')["house_type"].count()

draw_category_with_offset_limit(house_type_category, 0, 1)

# %%
district_category = categories.groupby('district')["district"].count()

draw_category_with_offset_limit(district_category, 0, 1)

# %%
town_category = categories.groupby('town')["town"].count()

draw_category_with_offset_limit(town_category, 0, 1)
draw_category_with_offset_limit(town_category, 1, 2)
draw_category_with_offset_limit(town_category, 2, 3)
draw_category_with_offset_limit(town_category, 3, 4)
draw_category_with_offset_limit(town_category, 4, 5)
draw_category_with_offset_limit(town_category, 5, 6)
draw_category_with_offset_limit(town_category, 6, 7)
draw_category_with_offset_limit(town_category, 7, 8)

# %% [markdown]
# <h5>What is the percentage of missing values?</h5>

# %%
percent_missing = categories.isnull().sum() * 100 / len(categories)
missing_value_df = pd.DataFrame({'column_name': categories.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#            column_name  percent_missing
# date              date         0.000000
# address        address         0.057643
# district      district         0.001226
# town              town         0.057643
# house_type  house_type         0.036793
